# %%
#Loop through a large range of integers and check if they are divisable by numbers in a given list, if yes output a code assosicated with that divisor
#Start with a loop i.e. a number, call in the divisor and call in the definition/function to check and outut correct code
#Use mod function

#Now setup definition/function

def mod_calc(number,divisors,code_given):
    list_len=len(divisors)
    answer = " "
         
    for k in range(0,list_len):
        #Take care of the first case number equal to zero
        if number == 0:
           number = 1
        #Clear answer
        answer = ' '
        #Do the math
        if number % divisors[k] == 0:
            answer = code_given.get(divisors[k])
        #If answer contains a code add to output list  
        if answer != ' ':
            output_list.append(answer)
    #Output from function is a list of codes as strings
            
    return output_list

#Input here manually given data
divisors = [3,5,7,11,13]
code_given = {3:'Fizz', 5:'Buzz', 7:'Wuzz', 11:'Nuzz', 13:'Luzz'}
loop_start = 0
loop_length = 1000

#Initilalise

number = 0
output_list =[]

#Now Main Program

print("Main program")
#Check length of list to help for loop
list_len=len(divisors)
#Clear list
output_list = []
#Deal with the range given, secondary loop is in definition/function
for i in range(loop_start,loop_length):
    #Call definition
    mod_calc(i,divisors,code_given)
    #Don't print empty list
    len_output = len(output_list)
    if output_list != []:
        space_less = ''
        print("Number",i,space_less.join(output_list))
    #Clear output_list on new loop
    output_list = []   

#test numbers are 15, 105, 1155 and 15015
# Out:
# Main program
# Number 3 Fizz
# Number 5 Buzz
# Number 6 Fizz
# Number 7 Wuzz
# Number 9 Fizz
# Number 10 Buzz
# Number 11 Nuzz
# Number 12 Fizz
# Number 13 Luzz
# Number 14 Wuzz
# Number 15 FizzBuzz
# Number 18 Fizz
# Number 20 Buzz
# Number 21 FizzWuzz
# Number 22 Nuzz
# Number 24 Fizz
# Number 25 Buzz
# Number 26 Luzz
# Number 27 Fizz
# Number 28 Wuzz
# Number 30 FizzBuzz
# Number 33 FizzNuzz
# Number 35 BuzzWuzz
# Number 36 Fizz
# Number 39 FizzLuzz
# Number 40 Buzz
# Number 42 FizzWuzz
# Number 44 Nuzz
# Number 45 FizzBuzz
# Number 48 Fizz
# Number 49 Wuzz
# Number 50 Buzz
# Number 51 Fizz
# Number 52 Luzz
# Number 54 Fizz
# Number 55 BuzzNuzz
# Number 56 Wuzz
# Number 57 Fizz
# Number 60 FizzBuzz
# Number 63 FizzWuzz
# Number 65 BuzzLuzz
# Number 66 FizzNuzz
# Number 69 Fizz
# Number 70 BuzzWuzz
# Number 72 Fizz
# Number 75 FizzBuzz
# Number 77 WuzzNuzz
# Number 78 FizzLuzz
# Number 80 Buzz
# Number 81 Fizz
# Number 84 FizzWuzz
# Number 85 Buzz
# Number 87 Fizz
# Number 88 Nuzz
# ...
